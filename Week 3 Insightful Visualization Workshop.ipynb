# %%
import pandas as pd
import numpy as np

# Load libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Import the data
file_path = 'Week 3 retail_dataset_extended.csv'
df = pd.read_csv(file_path)

# Output the data
print(df.head())

# Generate some basic statistical measures
print(df.describe())

# Placeholder for the box plot
# Box Plot: Create a box plot for the continuous variables in the dataset.
# sns.boxplot(data=df)
# plt.show()

# Placeholder for the scatter plot matrix
# Scatter Plot Matrix: Generate a scatter plot matrix to explore relationships between variables.
# sns.pairplot(df)
# plt.show()

# Placeholder for the correlation heat map
# Correlation Heat Map: Develop a correlation heat map to identify correlations between variables.
# numeric_df = df.select_dtypes(include=[np.number])
# sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
# plt.show()


# Placeholder for visualization of choice 1
# Visualization of Choice 1: Describe the visualization here.
# plt.show()


# Placeholder for visualization of choice 2
# Visualization of Choice 2: Describe the visualization here.
# Out:
#    OrderID    Product    Category       Sales  Quantity      Profit  \
# 0        1  Product C  Category 2  610.330074         9  204.722081
# 1        2  Product B  Category 3  164.211020         4  -14.798550
# 2        3  Product C  Category 1  650.629044         5  -99.579611
# 3        4  Product C  Category 2  715.975920         4  232.493884
# 4        5  Product C  Category 1  456.474448         5  204.699657
#
#    Customer_Age  Customer_Satisfaction  Discount_Percentage  Store_Area
# 0            65                     10            30.510542  440.725470
# 1            68                      1            12.879069  208.130897
# 2            27                      1            38.083231  121.359243
# 3            49                      1            41.709862  411.803761
# 4            52                      4            29.685547  403.440789
#           OrderID       Sales    Quantity      Profit  Customer_Age  \
# count  100.000000  100.000000  100.000000  100.000000     100.00000
# mean    50.500000  522.244548    5.270000  103.689449      43.71000
# std     29.011492  300.713517    2.326201  120.712631      15.57925
# min      1.000000   17.470345    1.000000  -99.692761      18.00000
# 25%     25.750000  243.174104    4.000000    2.746320      29.00000
# 50%     50.500000  561.535290    5.000000  110.678290      44.00000
# 75%     75.250000  762.476890    7.000000  204.964148      57.50000
# max    100.000000  996.907075    9.000000  298.914644      69.00000
#
#        Customer_Satisfaction  Discount_Percentage  Store_Area
# count             100.000000           100.000000  100.000000
# mean                5.650000            25.601774  330.386031
# std                 3.033067            15.219248  121.329914
# min                 1.000000             0.214894  101.350972
# 25%                 3.000000            10.939348  225.195551
# 50%                 5.000000            29.419369  357.919282
# 75%                 9.000000            40.100568  440.284545
# max                10.000000            49.675099  496.263691
